# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.11.0'

# %% [markdown]
#  **Convolution Neural Network**
#
#  Build a Convolution neural network with tensorflow 2.11.0
#
#
#  **CNN OverView**
#  ![Screenshot (146).png](data:image/png;base64,...)
#
#  You have an input and you know in last of every Architecture of Alexnet CNN. at the end what they do is they increase the number of feature map and decrease the number of dimension and once that has been done they flatten the whole thing out and once it has be flatted they form  dense layer across it and the reason why after flatening it out we directly do not go for an output of 10 neuron . the reason of 10 is becuase we use MNIST dataset

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
from keras.models import Sequential
from keras.layers import Dense,Dropout,Activation,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras import utils
from keras.utils import np_utils
import keras
from keras.datasets import mnist

# %% [markdown]
# ![Screenshot (148).png](data:image/png;base64,...)

# %% [markdown]
# **CV2**  -> Open CV
#
# **Sequential Model**  -> You have one layer which follow by another layer which is followed by a third layer and so on.
#
# So, we are importing Sequence kind of models the model that will be creating a Sequential model the layers are one after the other .
#
# **Layers import Dense , Dropout , Activation Function , Flatten** ->
#
# **Dense Layer** -> So , Dense layer  are basically we can create fully connected layer.
#
# **DropOut Layer** -> It dropout basically means thining out of the values this is use to prevent over fitting.
#
#
# **Activation** -> To add Activation
#
#
# **Flatten** -> You have all the dimension and finally to get the classification part the convolution are used to get the feature once you have the feature you can flatten out the feature and use those feature as input fully connected dense models that gives you the output.
#
#
# **From keras.layers imort Conv2D,MaxPooling2D**
#
# So, this 2 layers are Conv2D and Maxpooling 2D are basically layers that we will be using and adding to our already dense models
#
# " We have a Dense Layer then we add 2 more layer we will using we are adding conv2D and Maxpooling2D th8is 2 Layers we will using .
#
#
# **From keras.utils import utils**  -> Utils use basically used to plot the models.
# -> np.utlis -> this is basically we will be using it to converting to categoricals.
# " Number to Categorical "

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
y_train[0]
# Out:
# 5

# %%
fig,axes=plt.subplots(ncols=10,sharex=False,sharey=True,figsize=(20,4))
for i in range(10):
  axes[i].set_title(y_train[i])
  axes[i].imshow(x_train[i],cmap='gray')
  axes[i].get_xaxis().set_visible(False) #set_visible=False(We will not able to see axis value the whole grid thing not be able to to see)
  axes[i].get_yaxis().set_visible(False)
plt.show()

# %%
x_train=x_train.reshape(x_train.shape[0],28,28,1)
x_test=x_test.reshape(x_test.shape[0],28,28,1)
#1 is for hwo much channel we use

# %%
x_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
y_train.shape
# Out:
# (60000,)

# %%
x_train=x_train.astype('float64')
x_test=x_test.astype('float64')
x_train/=255
x_test/=255
y_train= np.utils.to_categorical(y_train,10)
y_test= np.utils.to_categorical(y_test,10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-031159129993> in <module>
#       3 x_train/=255
#       4 x_test/=255
# ----> 5 y_train= np.utils.to_categorical(y_train,10)
#       6 y_test= np.utils.to_categorical(y_test,10)
#
# /usr/local/lib/python3.8/dist-packages/numpy/__init__.py in __getattr__(attr)
#     313             return Tester
#     314
# --> 315         raise AttributeError("module {!r} has no attribute "
#     316                              "{!r}".format(__name__, attr))
#     317
#
# AttributeError: module 'numpy' has no attribute 'utils'
